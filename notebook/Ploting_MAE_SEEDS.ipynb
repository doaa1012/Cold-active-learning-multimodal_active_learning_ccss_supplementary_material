# %%
import pandas as pd
from matplotlib import colors
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append("..")
from config import *
from scripts.measurement_devices import *
import matplotlib.cm as cm
from scripts.run_active_learning import *
from scripts.plotting_MAE import *
import matplotlib.cm as cm
import os

# %%
base_strategies = [
    "Top5Similarity", "Max Comp", "Min Comp", 
    "Centroids_saturation_high", "Centroids_saturation_medium", "Centroids_saturation_low",
    "Random", "LHS", "K-Means", "Farthest", "K-Center", "ODAL"
]

base_dir = MAE_PLOT
filename = "Min Comp-10311_sawei_seeds.pdf"
save_path = os.path.join(base_dir, filename)

plot_average_mae_across_seeds(
    base_dir=Results_10311_sawei_seeds ,
    main_strategy="Min Comp",
    base_strategies=base_strategies,
    save_path=save_path
)

# %%
base_strategies = [
    "Top5Similarity", "Max Comp", "Min Comp", 
    "Centroids_saturation_high", "Centroids_saturation_medium", "Centroids_saturation_low",
    "Random", "LHS", "K-Means", "Farthest", "K-Center", "ODAL"
]
base_dir = MAE_PLOT
filename = "Max Comp-10311_uncertainty_seeds.pdf"
save_path = os.path.join(base_dir, filename)

plot_average_mae_across_seeds(
    base_dir=Results_10311_uncertainty_seeds,
    main_strategy="Max Comp",
    base_strategies=base_strategies,
    save_path=save_path
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
